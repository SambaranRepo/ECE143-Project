# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pylab import subplots
import pandas as pd
from matplotlib import cm
from IPython.display import display, HTML
import operator as op

# %%
data_dir = '../data/'

# %%
df_nips = pd.read_csv(data_dir + 'nips_2016-2020.csv')
df_icml = pd.read_csv(data_dir + 'icml_affiliations.csv')

df_iclr1 = pd.read_csv(data_dir + 'ICLR-2017-18-19-21.csv')
df_iclr2 = pd.read_csv(data_dir + '2020_iclr_manual_data.csv')
df_iclr = pd.concat([df_iclr1, df_iclr2], sort=True)
df_iclr = df_iclr.reset_index(drop=True)
df_cvpr = pd.read_csv(data_dir + 'cvpr_16-21.csv')

df_cvpr_citations = pd.read_csv(data_dir + 'cvpr_citations.csv')

# %%
df_cvpr['Authors']
for i in range(len(df_cvpr['Authors'])): 
    df_cvpr['Authors'] = df_cvpr['Authors'].str.replace(';',',')
    
for i in range(len(df_iclr['Citations'])):
    try:
        df_iclr['Citations'][i] = int(df_iclr['Citations'][i])
        df_iclr['YEAR'][i] = int(df_iclr['YEAR'][i])
    except Exception as e: 
        df_iclr['Citations'][i] = 0
        df_iclr['YEAR'][i] = df_iclr['YEAR'][i-1]
# Out:
# <ipython-input-32-dd3570a6c6d7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_iclr['Citations'][i] = int(df_iclr['Citations'][i])
# <ipython-input-32-dd3570a6c6d7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_iclr['YEAR'][i] = int(df_iclr['YEAR'][i])

# %%
years = df_nips['YEAR'].unique()
years
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021])

# %%
paper_per_year = {'NIPS': dict(),'ICML':dict(),'ICLR':dict(),'CVPR': dict()}
data = [df_nips, df_icml, df_iclr, df_cvpr]
num = 0
for key in paper_per_year.keys():
    print(key)
    pub_per_year = dict()

    for i in years: 
        pub_per_year.update({i:0})

    for i in range(len(data[num])):
        try:
            pub_per_year[data[num]['YEAR'][i]] +=1
        except:
            continue
    paper_per_year[key] = pub_per_year
    num+=1
# Out:
# NIPS
# ICML
# ICLR
# CVPR

# %%
paper_per_year['CVPR']
# Out:
# {2016: 643, 2017: 784, 2018: 1004, 2019: 1302, 2020: 1469, 2021: 1667}

# %%
fig,axs = subplots(1,1) 
axs.plot(years[1:], list(paper_per_year['NIPS'].values())[1:],marker = 'o', linestyle='--', markersize = 15, label = 'NeurIPS')
axs.plot(years[1:], list(paper_per_year['ICML'].values())[1:],marker = 'o', linestyle='--', markersize = 15, label = 'ICML')
axs.plot(years[1:], list(paper_per_year['ICLR'].values())[1:],marker = 'o', linestyle='--', markersize = 15, label = 'ICLR')
axs.plot(years[1:], list(paper_per_year['CVPR'].values())[1:],marker = 'o', linestyle='--', markersize = 15, label = 'CVPR')
axs.set_xlabel('Year', fontsize = 12)
axs.set_ylabel('Number of Papers published',fontsize = 12)
axs.spines['right'].set_visible(False)
axs.spines['top'].set_visible(False)
axs.set_title('Number of papers published')
axs.legend()

# %%
df_nips_citations = pd.read_csv(data_dir + 'nips_citations.csv')
df_icml_citations = pd.read_csv(data_dir + 'icml_citations.csv')
df_iclr_citations = pd.DataFrame({'YEAR':df_iclr['YEAR'], 'citations':df_iclr['Citations']})
df_iclr_citations['citations'].astype('int64').dtypes
type(df_iclr_citations['citations'][1994])
# Out:
# int

# %%
nips_2017 = df_nips_citations[df_nips_citations['YEAR']==2017].sort_values(by='citations', ascending = False)
nips_2018 = df_nips_citations[df_nips_citations['YEAR']==2018].sort_values(by='citations', ascending = False)
nips_2019 = df_nips_citations[df_nips_citations['YEAR']==2019].sort_values(by='citations', ascending = False)
print('Neurips {}'.format(2017))
display(HTML(nips_2017[['TITLE', 'citations']].head(n=10).to_html(index=False)))
# print('Neurips {}'.format(2018))
# display(HTML(nips_2018[['TITLE', 'citations']].head(n=10).to_html(index=False)))
# print('Neurips {}'.format(2019))
# display(HTML(nips_2019[['TITLE', 'citations']].head(n=10).to_html(index=False)))
# Out:
# Neurips 2017
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>TITLE</th>
#       <th>citations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Attention is All you Need</td>
#       <td>31339</td>
#     </tr>
#     <tr>
#       <td>Improved Training of Wasserstein GANs</td>
#       <td>5834</td>
#     </tr>
#     <tr>
#       <td>GANs Trained by a Two Time-Scale Update Rule Converge to a Local Nash Equilibrium</td>
#       <td>3971</td>
#     </tr>
#     <tr>
#       <td>Simple and Scalable Predictive Uncertainty Estimation using Deep Ensembles</td>
#       <td>2058</td>
#     </tr>
#     <tr>
#       <td>Unsupervised Image-to-Image Translation Networks</td>
#       <td>1882</td>
#     </tr>
#     <tr>
#       <td>Self-Normalizing Neural Networks</td>
#       <td>1733</td>
#     </tr>
#     <tr>
#       <td>Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments</td>
#       <td>1663</td>
#     </tr>
#     <tr>
#       <td>Hindsight Experience Replay</td>
#       <td>1258</td>
#     </tr>
#     <tr>
#       <td>A simple neural network module for relational reasoning</td>
#       <td>1201</td>
#     </tr>
#     <tr>
#       <td>Deep Sets</td>
#       <td>1189</td>
#     </tr>
#   </tbody>
# </table>

# %%
bins = [0,50,500,5000,50000,500000]

nips_citations_2017 = df_nips_citations[df_nips_citations['YEAR']==2017]['citations']
nips_citations_2018 = df_nips_citations[df_nips_citations['YEAR']==2018]['citations']
nips_citations_2019 = df_nips_citations[df_nips_citations['YEAR']==2019]['citations']
nips_citations_2020 = df_nips_citations[df_nips_citations['YEAR']==2020]['citations']

icml_citations_2017 = df_icml_citations[df_icml_citations['YEAR']==2017]['citations']
icml_citations_2018 = df_icml_citations[df_icml_citations['YEAR']==2018]['citations']
icml_citations_2019 = df_icml_citations[df_icml_citations['YEAR']==2019]['citations']
icml_citations_2020 = df_icml_citations[df_icml_citations['YEAR']==2020]['citations']

iclr_citations_2017 = df_iclr_citations[df_iclr_citations['YEAR']==2017]['citations']
iclr_citations_2018 = df_iclr_citations[df_iclr_citations['YEAR']==2018]['citations']
iclr_citations_2019 = df_iclr_citations[df_iclr_citations['YEAR']==2019]['citations']
iclr_citations_2020 = df_iclr_citations[df_iclr_citations['YEAR']==2020]['citations']

cvpr_citations_2017 = df_cvpr_citations[df_cvpr_citations['YEAR']==2017]['citations']
cvpr_citations_2018 = df_cvpr_citations[df_cvpr_citations['YEAR']==2018]['citations']
cvpr_citations_2019 = df_cvpr_citations[df_cvpr_citations['YEAR']==2019]['citations']
cvpr_citations_2020 = df_cvpr_citations[df_cvpr_citations['YEAR']==2020]['citations']




nips_citations = {2017:np.histogram(nips_citations_2017, bins), 2018:np.histogram(nips_citations_2018,bins),\
                  2019:np.histogram(nips_citations_2019,bins), 2020:np.histogram(nips_citations_2020,bins)}

icml_citations = {2017:np.histogram(icml_citations_2017,bins), 2018:np.histogram(icml_citations_2018,bins),\
                  2019:np.histogram(icml_citations_2019,bins), 2020:np.histogram(icml_citations_2020,bins)}

iclr_citations = {2017:np.histogram(iclr_citations_2017, bins), 2018:np.histogram(iclr_citations_2018, bins),\
                  2019:np.histogram(iclr_citations_2019, bins), 2020: np.histogram(iclr_citations_2020, bins)}

cvpr_citations = {2017:np.histogram(cvpr_citations_2017, bins),2018:np.histogram(cvpr_citations_2018, bins),\
                 2019:np.histogram(cvpr_citations_2019, bins),2020:np.histogram(cvpr_citations_2020, bins)}

# %%
years = list(nips_citations.keys())
fig,axs = subplots(2,2,figsize = (15,10))
for i in range(len(years)):
    axs[i//2, i%2].plot(list(nips_citations[years[i]][1][:-1]), list(100*nips_citations[years[i]][0])/sum(list(nips_citations[years[i]][0])),label='NeurIPS', linestyle = '--')
    axs[i//2,i%2].plot(list(icml_citations[years[i]][1][:-1]), list(100*icml_citations[years[i]][0])/sum(list(icml_citations[years[i]][0])),label='ICML', linestyle = '--')
    axs[i//2,i%2].plot(list(iclr_citations[years[i]][1][:-1]), list(100*iclr_citations[years[i]][0])/sum(list(iclr_citations[years[i]][0])), label='ICLR',linestyle = '--')
    axs[i//2,i%2].plot(list(cvpr_citations[years[i]][1][:-1]), list(100*cvpr_citations[years[i]][0])/sum(list(cvpr_citations[years[i]][0])), label='CVPR',linestyle = '--')
    axs[i//2,i%2].set_title(f'Citation comparison for {years[i]}')
    axs[i//2,i%2].set_xscale('log')
    axs[i//2,i%2].legend()

# %%
# df_whole = pd.concat([df_nips, df_iclr, df_icml, df_cvpr])
df_whole = pd.concat([df_nips, df_icml,df_iclr,df_cvpr])

# %%
affiliations = np.asarray(df_whole['Affiliations'])
aff_dict = dict()

for i in range(len(affiliations)):
    
    aff = str(affiliations[i]).replace('[','').replace(']','').replace('The','').split(', ')
    for entry in aff:
        entry = entry.replace("'",'')
        if entry not in aff_dict.keys():
            aff_dict.update({entry:1})
        else:
            aff_dict[entry] +=1
   
            
affil = dict(sorted(aff_dict.items(), key = op.itemgetter(1))[::-1])

def remove_duplicates(target_key, words):
    assert target_key in list(affil.keys())
    assert isinstance(words, list) and len(words) >= 1
    for key in list(affil.keys()): 
        if any(word in key.lower() for word in words)  : 
            affil[target_key] += affil[key]
            affil[key] = 0

remove_duplicates('Google', ['google','deepmind'])
words = ['uc san diego', 'university of california san diego',\
            'university of california at san diego','university of california, san diego','university of california']
remove_duplicates('UCSD',words)
remove_duplicates('MIT', ['massachusetts'])
remove_duplicates('Stanford', ['stanford uni'])
remove_duplicates('UCLA',['los angeles', 'university of california los angeles',\
                          'university of california, los angeles', 'university of california at los angeles'])
remove_duplicates('CMU',['Carnegie Mellon'])

#affil['UCSD']
#affil['MIT']
#affil['Stanford']

# %%
affil = dict((sorted(affil.items(), key = op.itemgetter(1))[::-1])[:20])
affil.pop('NA')
#affil.pop(' ')
# Out:
# 3236

# %%
fig,ax = subplots(figsize=(15,10))
ax.bar(affil.keys(), affil.values())
ax.set_xlabel('Institutes', fontsize = 15)
ax.set_ylabel('Publications', fontsize = 15)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor", fontsize = 15)
plt.setp(ax.get_yticklabels(),  fontsize = 15)
plt.title('Institutes most active in publications', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Institutes most active in publications')

# %%
authors = np.asarray(df_whole['Authors'])

# %%
author_dict = dict()
for row in authors: 
    row = str(row).split(', ')
    for entry in row: 
        if entry not in author_dict.keys():
            author_dict.update({entry:1})
        else: 
            author_dict[entry]+=1

# %%
author_dict = sorted(author_dict.items(), key = op.itemgetter(1))[::-1]

# %%
author_dict = dict(author_dict[:20])

# %%
fig,ax = subplots(figsize = (15,10))
ax.bar(author_dict.keys(), author_dict.values())
ax.set_xlabel('Authors', fontsize = 15)
ax.set_ylabel('Publications', fontsize = 15)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor",fontsize = 14)
plt.setp(ax.get_yticklabels(), fontsize = 14)
plt.title('Authors most active in publications')

#Try horizontal bar chart
# Out:
# Text(0.5, 1.0, 'Authors most active in publications')

# %%
affil_nips_2017 = np.asarray(df_nips[df_nips['YEAR']==2017]['Affiliations'])
affil_nips_2018 = np.asarray(df_nips[df_nips['YEAR']==2018]['Affiliations'])
affil_nips_2019 = np.asarray(df_nips[df_nips['YEAR']==2019]['Affiliations'])
affil_nips_2020 = np.asarray(df_nips[df_nips['YEAR']==2020]['Affiliations'])
affil_nips_2021 = np.asarray(df_nips[df_nips['YEAR']==2021]['Affiliations'])

affil_iclr_2017 = np.asarray(df_iclr[df_iclr['YEAR']==2017]['Affiliations'])
affil_iclr_2018 = np.asarray(df_iclr[df_iclr['YEAR']==2018]['Affiliations'])
affil_iclr_2019 = np.asarray(df_iclr[df_iclr['YEAR']==2019]['Affiliations'])
affil_iclr_2020 = np.asarray(df_iclr[df_iclr['YEAR']==2020]['Affiliations'])
affil_iclr_2021 = np.asarray(df_iclr[df_iclr['YEAR']==2021]['Affiliations'])

affil_icml_2017 = np.asarray(df_icml[df_icml['YEAR']==2017]['Affiliations'])
affil_icml_2018 = np.asarray(df_icml[df_icml['YEAR']==2018]['Affiliations'])
affil_icml_2019 = np.asarray(df_icml[df_icml['YEAR']==2019]['Affiliations'])
affil_icml_2020 = np.asarray(df_icml[df_icml['YEAR']==2020]['Affiliations'])
affil_icml_2021 = np.asarray(df_icml[df_icml['YEAR']==2021]['Affiliations'])

affil_cvpr_2017 = np.asarray(df_cvpr[df_cvpr['YEAR']==2017]['Affiliations'])
affil_cvpr_2018 = np.asarray(df_cvpr[df_cvpr['YEAR']==2018]['Affiliations'])
affil_cvpr_2019 = np.asarray(df_cvpr[df_cvpr['YEAR']==2019]['Affiliations'])
affil_cvpr_2020 = np.asarray(df_cvpr[df_cvpr['YEAR']==2020]['Affiliations'])
affil_cvpr_2021 = np.asarray(df_cvpr[df_cvpr['YEAR']==2021]['Affiliations'])

# %%
nips = {2017:[], 2018:[], 2019:[], 2020:[], 2021:[]}
icml = {2017:[], 2018:[], 2019:[], 2020:[], 2021:[]}
iclr = {2017:[], 2018:[], 2019:[], 2020:[], 2021:[]}
cvpr = {2017:[], 2018:[], 2019:[], 2020:[], 2021:[]}

affil_nips = {2017: affil_nips_2017, 2018: affil_nips_2018, 2019: affil_nips_2019, 2020: affil_nips_2020, 2021: affil_nips_2021}
affil_icml = {2017: affil_icml_2017, 2018: affil_icml_2018, 2019: affil_icml_2019, 2020: affil_icml_2020, 2021: affil_icml_2021}
affil_iclr = {2017: affil_iclr_2017, 2018: affil_iclr_2018, 2019: affil_iclr_2019, 2020: affil_iclr_2020,2021: affil_iclr_2021}
affil_cvpr = {2017: affil_cvpr_2017, 2018: affil_cvpr_2018, 2019: affil_cvpr_2019, 2020: affil_cvpr_2020, 2021: affil_cvpr_2021 }

affil = [affil_nips, affil_icml, affil_iclr, affil_cvpr]

# nips_2017,nips_2018,nips_2019,nips_2020 = [],[],[],[]
# iclr_2017,iclr_2018,iclr_2019,iclr_2021 = [],[],[],[]
# def get_names(arr, affil):
#     assert isinstance(arr, list)
#     for i in range(len(affil)): 
#         row = str(affil[i]).replace('[','').replace(']','').replace('\n',',').split(', ')
#         for entry in row:
#             arr.append(entry.lower().replace("'",'').replace("'",'').replace('"',''))
            
data = [nips, icml, iclr, cvpr]
years = range(2017,2022)

for i in range(len(data)): 
    for year in years:
        for k in range(len(affil[i][year])):
            row = str(affil[i][year][k]).replace('[','').replace(']','').replace('\n',',').split(', ')
            for entry in row:
                data[i][year].append(entry.lower().replace("'",'').replace("'",'').replace('"',''))
        
# get_names(nips_2017,affil_nips_2017)
# get_names(nips_2018,affil_nips_2018)
# get_names(nips_2019,affil_nips_2019)
# get_names(nips_2020,affil_nips_2020)
# get_names(iclr_2017, affil_iclr_2017)
# get_names(iclr_2018, affil_iclr_2018)
# get_names(iclr_2019, affil_iclr_2019)
# get_names(iclr_2021, affil_iclr_2021)

# %%
uni_keywords = ['uni','tech','uc','mit','ui','eth','epfl','inst','college']
industry_kewords = ['google','microsoft','adobe','amazon','deepmind','ai','research','systems','nvidia','amd']

# %%
nips_university = {2017:0, 2018:0,2019:0,2020:0,2021:0}
nips_industry = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(nips_university.keys())
names = [nips[2017],nips[2018],nips[2019],nips[2020],nips[2021]]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords): 
            nips_university[year] +=1
        else: 
            nips_industry[year]+=1
            

            
icml_university = {2017:0, 2018:0,2019:0,2020:0,2021:0}
icml_industry = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(icml_university.keys())
names = [icml[2017],icml[2018],icml[2019],icml[2020],icml[2021]]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords): 
            icml_university[year] +=1
        else:
            icml_industry[year]+=1
            

iclr_university = {2017:0, 2018:0,2019:0,2020:0,2021:0}
iclr_industry = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(iclr_university.keys())
names = [iclr[2017],iclr[2018],iclr[2019],iclr[2020],iclr[2021]]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords): 
            iclr_university[year] +=1
        else:
            iclr_industry[year]+=1

cvpr_university = {2017:0, 2018:0,2019:0,2020:0,2021:0}
cvpr_industry = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(cvpr_university.keys())
names = [cvpr[2017],cvpr[2018],cvpr[2019],cvpr[2020],cvpr[2021]]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords): 
            cvpr_university[year] +=1
        else:
            cvpr_industry[year]+=1

# %%
nips_university
# Out:
# {2017: 1659, 2018: 2603, 2019: 3762, 2020: 5228, 2021: 7247}

# %%
nips_industry
# Out:
# {2017: 1003, 2018: 1528, 2019: 2229, 2020: 3138, 2021: 3744}

# %%
icml_university
# Out:
# {2017: 942, 2018: 1514, 2019: 1867, 2020: 2787, 2021: 3193}

# %%
icml_industry
# Out:
# {2017: 683, 2018: 920, 2019: 1191, 2020: 1716, 2021: 1966}

# %%
iclr_university
# Out:
# {2017: 237, 2018: 758, 2019: 1256, 2020: 326, 2021: 1302}

# %%
iclr_industry
# Out:
# {2017: 237, 2018: 760, 2019: 1042, 2020: 201, 2021: 950}

# %%
cvpr_university
# Out:
# {2017: 1804, 2018: 2460, 2019: 4068, 2020: 5898, 2021: 5861}

# %%
cvpr_industry
# Out:
# {2017: 1386, 2018: 1902, 2019: 1846, 2020: 2265, 2021: 2349}

# %%
total_university = dict()
total_industry = dict()
for key in list(cvpr_industry.keys()):
    total_university[key] = nips_university[key] + icml_university[key] + iclr_university[key] + cvpr_university[key]
    total_industry[key] = nips_industry[key] + icml_industry[key] + iclr_industry[key] + cvpr_industry[key]

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(total_university.keys()))
bar_width = 0.2
axs.bar(years, total_university.values(), width=bar_width, label = 'Academia')
axs.bar(years + bar_width, total_industry.values(), width = bar_width, label = 'Industry')
axs.set_xticks(years + bar_width/2)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Total Publications by university and industry for each year', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Total Publications by university and industry for each year')

# %%
'uni' in 'university of technology sydney'
# Out:
# True

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(nips_university.keys()))
bar_width = 0.2
axs.bar(years, nips_university.values(), width=bar_width, label = 'Academia')
axs.bar(years + bar_width, nips_industry.values(), width = bar_width, label = 'Industry')
axs.set_xticks(years + bar_width/2)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Publications by university and industry in NeurIPS', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Publications by university and industry in NeurIPS')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(icml_university.keys()))
bar_width = 0.2
axs.bar(years, icml_university.values(), width=bar_width, label = 'Academia')
axs.bar(years + bar_width, icml_industry.values(), width = bar_width, label = 'Industry')
axs.set_xticks(years + bar_width/2)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Publications by university and industry in ICML', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Publications by university and industry in ICML')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(iclr_university.keys()))
bar_width = 0.2
axs.bar(years, iclr_university.values(), width=bar_width, label = 'Academia')
axs.bar(years + bar_width, iclr_industry.values(), width = bar_width, label = 'Industry')
axs.set_xticks(years + bar_width/2)
axs.set_xticklabels(years)
# axs.spines['top'].set_visible(False)
axs.legend(fontsize = 10)
axs.set_title('Publications by university and industry in ICLR', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Publications by university and industry in ICLR')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(cvpr_university.keys()))
bar_width = 0.2
axs.bar(years, cvpr_university.values(), width=bar_width, label = 'Academia')
axs.bar(years + bar_width, cvpr_industry.values(), width = bar_width, label = 'Industry')
axs.set_xticks(years + bar_width/2)
axs.set_xticklabels(years)
# axs.spines['top'].set_visible(False)
axs.legend(fontsize = 10)
axs.set_title('Publications by university and industry in CVPR', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Publications by university and industry in CVPR')

# %%
industry_kewords = ['google','microsoft','adobe','amazon','deepmind','ai','research','systems','nvidia','amd']

# %%
industry = pd.DataFrame(columns=['keywords'])
industry['keywords'] = industry_kewords

# %%
industry
# Out:
#     keywords
# 0     google
# 1  microsoft
# 2      adobe
# 3     amazon
# 4   deepmind
# 5         ai
# 6   research
# 7    systems
# 8     nvidia
# 9        amd

# %%
industry.to_csv(data_dir + 'industry_keywords.csv')

# %% [markdown]
# # Collaboration of UCSD with industry

# %%
def get_affiliations(aff): 
    for i in range(len(aff)): 
        aff[i] = str(aff[i]).replace("'",'').replace("'",'').replace('"','').replace('"','').replace('[','').replace(']','').lower()

# %%
get_affiliations(affil_nips_2017)
get_affiliations(affil_nips_2018)
get_affiliations(affil_nips_2019)
get_affiliations(affil_nips_2020)
get_affiliations(affil_nips_2021)

get_affiliations(affil_icml_2017)
get_affiliations(affil_icml_2018)
get_affiliations(affil_icml_2019)
get_affiliations(affil_icml_2020)
get_affiliations(affil_icml_2021)

get_affiliations(affil_iclr_2017)
get_affiliations(affil_iclr_2018)
get_affiliations(affil_iclr_2019)
get_affiliations(affil_iclr_2020)
get_affiliations(affil_iclr_2021)

get_affiliations(affil_cvpr_2017)
get_affiliations(affil_cvpr_2018)
get_affiliations(affil_cvpr_2019)
get_affiliations(affil_cvpr_2020)
get_affiliations(affil_cvpr_2021)

# %%
affil_cvpr_2017
# Out:
# array(['univ. of minnesota  minneapolis  mn  usa, univ. of minnesota  minneapolis  mn  usa',
#        'university of technology sydney  broadway  ultimo  nsw 2007  australia, cvpr unit  indian statistical institute  kolkata 700108  india, cvpr unit  indian statistical institute  kolkata 700108  india, cvpr unit  indian statistical institute  kolkata 700108  india, university of technology sydney  broadway  ultimo  nsw 2007  australia',
#        'gonda multidiscipl. brain res. center  bar ilan univ.  ramat gan  israel, blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel',
#        'sch. of comput. sci. & software eng.  univ. of western australia  crawley  wa  australia, nat. univ. of sci. & technol.  islamabad  pakistan, sch. of comput. sci. & software eng.  univ. of western australia  crawley  wa  australia',
#        'uc san diego  san diego  ca  usa, univ. of salzburg  salzburg  austria, unc chapel hill  chapel hill  nc  usa, uc san diego  san diego  ca  usa',
#        'comput. vision lab.  eth zurich  zurich  switzerland, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, computer vision laboratory  eth zurich  switzerland',
#        'sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china',
#        'na, na, na', 'na, na',
#        'beijing adv. innovation center for big data & brain comput.  beihang univ.  beijing  china, beijing adv. innovation center for big data & brain comput.  beihang univ.  beijing  china, beijing adv. innovation center for big data & brain comput.  beihang univ.  beijing  china, na, sch. of comput. sci.  univ. of east anglia  norwich  uk',
#        'na, na, na, na, na, na, na, na',
#        'binghamton univ.  binghamton  ny  usa, ibm res.  yorktown heights  ny  usa, ibm res.  yorktown heights  ny  usa, ibm res.  yorktown heights  ny  usa, uc san diego  la jolla  ca  usa, binghamton univ.  binghamton  ny  usa, ibm res.  yorktown heights  ny  usa',
#        'australian nat. univ.  canberra  act  australia, australian nat. univ.  canberra  act  australia',
#        'na, na, na, na',
#        'fbk  trento  italy, mapillary  graz  austria, mapillary  graz  austria',
#        'na, na, na, na',
#        'intel labs. china  beijing  china, intel labs. china  beijing  china, dept. of electron. eng.  tsinghua univ.  beijing  china, intel labs. china  beijing  china',
#        'georgia inst. of technol.  atlanta  ga  usa, carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, sun yat-sen univ.  guangzhou  china, carnegie mellon univ.  pittsburgh  pa  usa, georgia inst. of technol.  atlanta  ga  usa',
#        'stanford university, facebook ai research, facebook ai research, stanford university, facebook ai research, facebook ai research',
#        'max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany',
#        'nat. taiwan univ.  taipei  taiwan, nat. taiwan univ.  taipei  taiwan, nat. taiwan univ.  taipei  taiwan, nat. taiwan univ.  taipei  taiwan',
#        'imperial coll. london  london  uk, imperial coll. london  london  uk, imperial coll. london  london  uk, imperial coll. london  london  uk',
#        'na, na, na, na',
#        'sch. of comput. eng.  nanyang technol. univ.  singapore  singapore, inst. for infocomm res.  agency for sci.  technol. & res.  singapore  singapore, sch. of comput. eng.  nanyang technol. univ.  singapore  singapore',
#        'cai  univ. of technol. sydney  sydney  nsw  australia, cai  univ. of technol. sydney  sydney  nsw  australia, cai  univ. of technol. sydney  sydney  nsw  australia',
#        'dept. of comput.  imperial coll. london  london  uk, mit media lab.  cambridge  ma  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, dept. of comput.  imperial coll. london  london  uk, dept. of comput.  imperial coll. london  london  uk',
#        'korea univ.  seoul  south korea, korea univ.  seoul  south korea',
#        'na, na',
#        'king abdullah univ. of sci. & technol. (kaust)  thuwal  saudi arabia, king abdullah univ. of sci. & technol. (kaust)  thuwal  saudi arabia, king abdullah univ. of sci. & technol. (kaust)  thuwal  saudi arabia',
#        'key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china',
#        'univ. of sci. & technol. of china  hefei  china, univ. of sci. & technol. of china  hefei  china, univ. of sci. & technol. of china  hefei  china, microsoft res.  beijing  china',
#        'na, na, na, na, na, na',
#        'german res. center for artificial intell.  saarbrucken  germany, german res. center for artificial intell.  saarbrucken  germany, german res. center for artificial intell.  saarbrucken  germany',
#        'sch. of comput. sci.  carnegie mellon univ.  pittsburgh  pa  usa, sch. of comput. sci.  carnegie mellon univ.  pittsburgh  pa  usa, sch. of comput. sci.  carnegie mellon univ.  pittsburgh  pa  usa',
#        'dept. of comput. sci.  univ. of wisconsin  madison  wi  usa, dept. of biostat. & med. inf.  univ. of wisconsin  madison  wi  usa, dept. of comput. sci.  univ. of wisconsin  madison  wi  usa, grecc  william s. middleton va hosp.  madison  wi  usa, dept. of biostat. & med. inf.  univ. of wisconsin  madison  wi  usa',
#        'dept. of ece  seoul nat. univ.  seoul  south korea, dept. of ece  seoul nat. univ.  seoul  south korea, dept. of ece  seoul nat. univ.  seoul  south korea',
#        'princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, adobe res.  san jose  ca  usa, adobe res.  san jose  ca  usa, princeton univ.  princeton  nj  usa',
#        'univ. of toronto  toronto  on  canada, canadian inst. for adv. res.  toronto  on  canada',
#        'comput. vision center  uab  e-barcelona  spain, cvit  iiit hyderabad  hyderabad  india, comput. vision center  uab  e-barcelona  spain, comput. vision center  uab  e-barcelona  spain, cvit  iiit hyderabad  hyderabad  india',
#        'shanghai jiao tong univ.  shanghai  china, shanghai jiao tong univ.  shanghai  china, univ. of adelaide  adelaide  sa  australia, shanghai jiao tong univ.  shanghai  china, shanghai jiao tong univ.  shanghai  china',
#        'carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa',
#        'dept. of ece  seoul nat. univ.  seoul  south korea, dept. of ece  seoul nat. univ.  seoul  south korea',
#        'na, na, na, na, na, na',
#        'tsinghua univ.  beijing  china, tsinghua univ.  beijing  china, cardiff univ.  cardiff  uk',
#        'na, na, na',
#        'center for cognitive ubiquitous comput.  arizona state univ.  tempe  az  usa, center for cognitive ubiquitous comput.  arizona state univ.  tempe  az  usa, center for cognitive ubiquitous comput.  arizona state univ.  tempe  az  usa, center for cognitive ubiquitous comput.  arizona state univ.  tempe  az  usa',
#        'na, na, na', 'na, na, na, na, na',
#        'univ. of california  berkeley  berkeley  ca  usa, univ. of california  berkeley  berkeley  ca  usa, univ. of california  san diego  la jolla  ca  usa',
#        'carnegie mellon univ.  pittsburgh  pa  usa, beijing inst. of technol.  beijing  china, carnegie mellon univ.  pittsburgh  pa  usa',
#        'alan turing inst.  univ. of oxford  oxford  uk, alan turing inst.  univ. of oxford  oxford  uk',
#        'nlpr  inst. of autom.  beijing  china, nlpr  inst. of autom.  beijing  china, nlpr  inst. of autom.  beijing  china, nlpr  inst. of autom.  beijing  china',
#        'na, na, na, na, na',
#        'mpi inf.  saarbrücken  germany, mpi inf.  saarbrücken  germany, mpi inf.  saarbrücken  germany, comput. lab.  univ. of cambridge  cambridge  uk, mpi inf.  saarbrücken  germany, mpi inf.  saarbrücken  germany, mpi inf.  saarbrücken  germany',
#        'na, na, na, na',
#        'massachusetts inst. of technol.  cambridge  ma  usa, massachusetts inst. of technol.  cambridge  ma  usa, massachusetts inst. of technol.  cambridge  ma  usa',
#        'na, na, sch. of sci. & eng.  univ. of dundee  dundee  uk, na',
#        'na, na, na', 'caltech, caltech, caltech', 'na, na, na, na, na',
#        'na, na, na', 'na, na, na',
#        'dept. of comput. sci. & eng.  waseda univ.  tokyo  japan, dept. of comput. sci. & eng.  waseda univ.  tokyo  japan, dept. of comput. sci. & eng.  waseda univ.  tokyo  japan, dept. of comput. sci. & eng.  waseda univ.  tokyo  japan',
#        'johns hopkins univ.  baltimore  md  usa, johns hopkins univ.  baltimore  md  usa, johns hopkins univ.  baltimore  md  usa, johns hopkins univ.  baltimore  md  usa, johns hopkins univ.  baltimore  md  usa',
#        'korea univ.  seoul  south korea, korea univ.  seoul  south korea',
#        'media analytics dept.  nec labs. america  cupertino  ca  usa, media analytics dept.  nec labs. america  cupertino  ca  usa, media analytics dept.  nec labs. america  cupertino  ca  usa, media analytics dept.  nec labs. america  cupertino  ca  usa',
#        'na, na, na, na, na',
#        'max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany',
#        'hikvision res. inst.  hangzhou  china, hikvision res. inst.  hangzhou  china, hikvision res. inst.  hangzhou  china',
#        'na, na, na, na',
#        'osaka univ.  suita  japan, osaka univ.  suita  japan, osaka univ.  suita  japan, nanjing univ. of sci. & technol.  nanjing  china, osaka univ.  suita  japan',
#        'dept. of electr. & comput. eng.  univ. of california  san diego  la jolla  ca  usa, dept. of electr. & comput. eng.  univ. of california  san diego  la jolla  ca  usa',
#        'dept. of comput. sci.  goethe univ.  frankfurt  germany, dept. of psychol.  tech. univ. darmstadt  darmstadt  germany, dept. of comput. sci.  goethe univ.  frankfurt  germany',
#        'na, na, na, na',
#        'paul g. allen sch. of comput. sci. & eng.  univ. of washington  seattle  wa  usa, paul g. allen sch. of comput. sci. & eng.  univ. of washington  seattle  wa  usa',
#        'na, na',
#        'kaust  thuwal  saudi arabia, chung-ang univ.  seoul  south korea, georgia tech  atlanta  ga  usa, kaust  thuwal  saudi arabia',
#        'na, na, na, na', 'na, na, na, na, na, na',
#        'inst. of cyber-syst. & control  zhejiang univ.  hangzhou  china, inst. of cyber-syst. & control  zhejiang univ.  hangzhou  china, exacloud ltd.  hangzhou  china',
#        'na, na, na, na',
#        'berkeley ai res. (bair) lab.  univ. of california  berkeley  berkeley  ca  usa, berkeley ai res. (bair) lab.  univ. of california  berkeley  berkeley  ca  usa, berkeley ai res. (bair) lab.  univ. of california  berkeley  berkeley  ca  usa',
#        'esat-psi  ku leuven  leuven  belgium, esat-psi  ku leuven  leuven  belgium, esat-psi  ku leuven  leuven  belgium',
#        'univ. laval  quebec city  qc  canada, na, na, na, univ. laval  quebec city  qc  canada',
#        'na, na, na, na, na, na',
#        'stony brook univ.  stony brook  ny  usa, na, na, na, na, stony brook univ.  stony brook  ny  usa',
#        'southern illinois univ.  carbondale  il  usa, southern illinois univ.  carbondale  il  usa, southern illinois univ.  carbondale  il  usa',
#        'saarland inf. campus  max planck inst. for inf.  saarbrϋcken  germany, saarland inf. campus  max planck inst. for inf.  saarbrϋcken  germany, univ. of mannheim  mannheim  germany, saarland inf. campus  max planck inst. for inf.  saarbrϋcken  germany',
#        'univ. of maryland  college park  md  usa, weizmann inst. of sci.  rehovot  israel, weizmann inst. of sci.  rehovot  israel, univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa, princeton univ.  princeton  nj  usa, weizmann inst. of sci.  rehovot  israel',
#        'eskisehir osmangazi  univ. meselik kampusu  eskisehir  turkey, lab. jean kuntzmann  grenoble  france',
#        'na, na, na', 'na, na, na, na, na, na, na',
#        'sch. of eic  huazhong univ. of sci. & technol.  wuhan  china, sch. of eic  huazhong univ. of sci. & technol.  wuhan  china, sch. of eic  huazhong univ. of sci. & technol.  wuhan  china, sch. of eic  huazhong univ. of sci. & technol.  wuhan  china',
#        'nat. lab. of pattern recognition  inst. of autom.  beijing  china, nat. lab. of pattern recognition  inst. of autom.  beijing  china, nat. lab. of pattern recognition  inst. of autom.  beijing  china',
#        'na, pattern anal. & comput. vision  ist. italiano di tecnol.  italy, pattern anal. & comput. vision  ist. italiano di tecnol.  italy, na',
#        'na, na, na, na',
#        'dept. of electron. & electr. eng.  univ. of sheffield  sheffield  uk, sch. of comput. sci.  univ. of east anglia  norwich  uk, dept. of electron. & electr. eng.  univ. of sheffield  sheffield  uk',
#        'na, na, na, na', 'na, na',
#        'queen mary  univ. of london  london  uk, queen mary  univ. of london  london  uk, queen mary  univ. of london  london  uk',
#        'dept. of comput. sci. & eng.  nanjing univ. of sci. & technol.  nanjing  china, dept. of comput. sci. & eng.  nanjing univ. of sci. & technol.  nanjing  china, dept. of comput. sci. & eng.  michigan state univ.  east lansing  mi  usa',
#        'na, na, na, na',
#        'gen. electr. global res. center  niskayuna  ny  usa, gen. electr. global res. center  niskayuna  ny  usa, gen. electr. global res. center  niskayuna  ny  usa',
#        'na, na, na',
#        'iie  univ. de la republica  montevideo  uruguay, ece  duke univ.  durham  nh  usa, ece  duke univ.  durham  nh  usa',
#        'eece  univ. of chinese acad. of sci.  beijing  china, eece  univ. of chinese acad. of sci.  beijing  china, eece  univ. of chinese acad. of sci.  beijing  china, ece  duke univ.  durham  nh  usa, univ. of oulu  oulu  finland, ece  duke univ.  durham  nh  usa, asee  beihang univ.  beijing  china',
#        'na, na, na, na, na',
#        'dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china',
#        'key lab. of underwater acoust. commun. & marine inf. technol.  xiamen univ.  xiamen  china, key lab. of underwater acoust. commun. & marine inf. technol.  xiamen univ.  xiamen  china, sch. of math.  south china univ. of technol.  guangzhou  china, key lab. of underwater acoust. commun. & marine inf. technol.  xiamen univ.  xiamen  china, key lab. of underwater acoust. commun. & marine inf. technol.  xiamen univ.  xiamen  china, dept. of electr. eng. & data sci. inst.  columbia univ.  new york  ny  usa',
#        'na, na, na, na, na',
#        'ecole des ponts paristech  univ. paris est  paris  france, ecole des ponts paristech  univ. paris est  paris  france',
#        'oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa',
#        'sch. of comput. & commun. sci.  ecole polytech. fed. de lausanne  lausanne  switzerland, sch. of comput. & commun. sci.  ecole polytech. fed. de lausanne  lausanne  switzerland, sch. of comput. & commun. sci.  ecole polytech. fed. de lausanne  lausanne  switzerland',
#        'dept. of radiol. & imaging sci.  nat. inst. of health  bethesda  md  usa, nat. center for biotechnol. inf.  nat. inst. of health  bethesda  md  usa, dept. of radiol. & imaging sci.  nat. inst. of health  bethesda  md  usa, nat. center for biotechnol. inf.  nat. inst. of health  bethesda  md  usa, dept. of radiol. & imaging sci.  nat. inst. of health  bethesda  md  usa, dept. of radiol. & imaging sci.  nat. inst. of health  bethesda  md  usa',
#        'univ. of illinois at urbana champaign  champaign  il  usa, na, univ. of illinois at urbana champaign  champaign  il  usa',
#        'na, na, na', 'na, na, na, na, na, na',
#        'na, na, australian nat. univ.  canberra  act  australia',
#        'lab. for imagery  vision & artificial intell.  ecole de technol. super.  montreal  qc  canada, laboratory for imagery  vision and artificial intelligence  ecole de technologie superieure  montreal  canada, lab. for imagery  vision & artificial intell.  ecole de technol. super.  montreal  qc  canada',
#        'imperial coll. london  london  uk, amazon  berlin  germany, imperial coll. london  london  uk, imperial coll. london  london  uk, imperial coll. london  london  uk, imperial coll. london  london  uk',
#        'univ. of north carolina at chapel hill  chapel hill  nc  usa, na, na, na, univ. of north carolina at chapel hill  chapel hill  nc  usa',
#        'univ. of california  santa barbara  santa barbara  ca  usa, adobe res.  san francisco  ca  usa, univ. of california  santa barbara  santa barbara  ca  usa, univ. of california  santa barbara  santa barbara  ca  usa',
#        'stanford univ.  stanford  ca  usa, princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa, stanford univ.  stanford  ca  usa',
#        'na, na, na, na',
#        'dalian univ. of technol.  dalian  china, dalian univ. of technol.  dalian  china, dalian univ. of technol.  dalian  china, dalian univ. of technol.  dalian  china, dalian univ. of technol.  dalian  china, dalian univ. of technol.  dalian  china, tiwaki co. ltd.  japan',
#        'univ. of bern  bern  switzerland, tech. univ. darmstadt  darmstadt  germany, univ. of bern  bern  switzerland',
#        'dept. of comput. sci.  stanford univ.  stanford  ca  usa, dept. of comput. sci.  univ. of southern california  los angeles  ca  usa, dept. of comput. sci.  stanford univ.  stanford  ca  usa',
#        'na, na, na, na, na, na', 'na, na, na, na',
#        'luxembourg centre for syst. biomed.  univ. of luxembourg  luxembourg  luxembourg, tech. univ. of munich  munich  germany, luxembourg centre for syst. biomed.  univ. of luxembourg  luxembourg  luxembourg, tech. univ. of munich  munich  germany',
#        'na, na, na',
#        'univ. of sci. & technol. of china  hefei  china, microsoft res.  beijing  china, microsoft res.  beijing  china, univ. of sci. & technol. of china  hefei  china, microsoft res.  beijing  china',
#        'univ. of montreal  montreal  qc  canada, univ. lille  cnrs  centrale lille  inria  umr 9189 cristal, university of montreal  montreal  qc  canada, deepmind, twitter, univ. of montreal  montreal  qc  canada',
#        'sch. of comput. sci. & technol.  harbin inst. of technol.  harbin  china, sch. of comput. sci. & technol.  harbin inst. of technol.  harbin  china, dept. of comput.  hong kong polytech. univ.  hong kong  china, dept. of comput.  hong kong polytech. univ.  hong kong  china',
#        'dept. of electr.  electron. & comput. eng.  catania  italy, dept. of electr.  electron. & comput. eng.  catania  italy, dept. of electr.  electron. & comput. eng.  catania  italy, dept. of electr.  electron. & comput. eng.  catania  italy, center for res. in comput. vision  univ. of central florida  orlando  fl  usa, center for res. in comput. vision  univ. of central florida  orlando  fl  usa',
#        'karlsruhe inst. of technol.  karlsruhe  germany, karlsruhe inst. of technol.  karlsruhe  germany',
#        'tech. univ. of munich  munich  germany, tech. univ. of munich  munich  germany, univ. of copenhagen  copenhagen  denmark, univ. of toulouse  toulouse  france, tech. univ. of munich  munich  germany',
#        'na, na, na, na, na',
#        'oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa',
#        'adv. multimedia res. lab.  univ. of wollongong  wollongong  nsw  australia, adv. multimedia res. lab.  univ. of wollongong  wollongong  nsw  australia, adv. multimedia res. lab.  univ. of wollongong  wollongong  nsw  australia',
#        'na, na, na, na, na, na',
#        'univ. of texas at austin  austin  tx  usa, univ. of texas at austin  austin  tx  usa, univ. of texas at austin  austin  tx  usa',
#        'univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa, univ. of colorado  boulder  co  usa, univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa',
#        'inf. technol. inst.  centre for res. & technol. hellas  thessaloniki  greece, inf. technol. inst.  centre for res. & technol. hellas  thessaloniki  greece, inf. technol. inst.  centre for res. & technol. hellas  thessaloniki  greece, dept. of electr. & comput. eng.  univ. of thessaly  volos  greece',
#        'na, na',
#        'univ. of wurzburg  wurzburg  germany, univ. of wurzburg  wurzburg  germany',
#        'na, na, na', 'na, na, na, na', 'na, na, na, na, na',
#        'center for machine perception  czech tech. univ. in prague  prague  czech republic, inst. of inf. theor. & autom.  prague  czech republic, inst. of inf. theor. & autom.  prague  czech republic, center for machine perception  czech tech. univ. in prague  prague  czech republic, center for machine perception  czech tech. univ. in prague  prague  czech republic',
#        'mpi for intell. syst.  tubingen  germany, mpi for intell. syst.  tubingen  germany, mpi for intell. syst.  tubingen  germany, mpi for intell. syst.  tubingen  germany',
#        'na, na, na', 'na, na, na',
#        'university of miami  fl  usa, univ. of florida  gainesville  fl  usa, univ. of florida  gainesville  fl  usa, univ. of florida  gainesville  fl  usa',
#        'sch. of comput. sci. & eng.  uestc  chengdu  china, sch. of comput. sci. & eng.  uestc  chengdu  china, center for robot.  uestc  chengdu  china, sch. of comput. sci. & eng.  uestc  chengdu  china, sch. of comput. sci. & eng.  uestc  chengdu  china',
#        'electr. & comput. eng. dept.  univ. of pittsburgh  pittsburgh  pa  usa, electr. & comput. eng. dept.  univ. of pittsburgh  pittsburgh  pa  usa, lg san jose lab.  santa clara  ca  usa, lg san jose lab.  santa clara  ca  usa, electr. & comput. eng. dept.  duke univ.  durham  nc  usa, electr. & comput. eng. dept.  duke univ.  durham  nc  usa',
#        'tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, na, na, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany',
#        'tel-aviv univ.  tel aviv  israel, tel-aviv univ.  tel aviv  israel',
#        'imperial coll. london  london  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, imperial coll. london  london  uk',
#        'dept. of electron. & electr. eng.  univ. of sheffield  sheffield  uk, sch. of comput. sci.  univ. of east anglia  norwich  uk, sch. of comput. sci.  univ. of east anglia  norwich  uk, center for future media  univ. of electron. sci. & technol. of china  chengdu  china, sch. of software  tsinghua univ.  beijing  china, dept. of comput. sci. & digital technol.  northumbria univ.  newcastle upon tyne  uk',
#        'columbia univ.  new york  ny  usa, columbia univ.  new york  ny  usa, columbia univ.  new york  ny  usa, mitsubishi electr.  japan, columbia univ.  new york  ny  usa',
#        'na, na, na, na', 'na, na, na, na, na',
#        'inst. for comput. graphics & vision  graz univ. of technol.  graz  austria, inst. for comput. graphics & vision  graz univ. of technol.  graz  austria, inst. for comput. graphics & vision  graz univ. of technol.  graz  austria, inst. for comput. graphics & vision  graz univ. of technol.  graz  austria',
#        'king abdullah univ. of sci. & technol.  thuwal  saudi arabia, king abdullah univ. of sci. & technol.  thuwal  saudi arabia, king abdullah univ. of sci. & technol.  thuwal  saudi arabia, king abdullah univ. of sci. & technol.  thuwal  saudi arabia',
#        'na, na, na, na, na, na',
#        'dept. of eng.  univ. of cambridge  cambridge  uk, dept. of eng.  univ. of cambridge  cambridge  uk, dept. of eng.  univ. of cambridge  cambridge  uk',
#        'esat-psi  ku leuven  leuven  belgium, cv:hci  karlsruhe inst. of technol.  karlsruhe  germany, sharif univ.  tehran  iran, univ. of maryland baltimore county  baltimore  md  usa, esat-psi  ku leuven  leuven  belgium',
#        'shenzhen univ.  shenzhen  china, univ. of illinois at chicago  chicago  il  usa, beijing univ. of posts & telecommun.  beijing  china, univ. of illinois at chicago  chicago  il  usa, shenzhen univ.  shenzhen  china, univ. of illinois at chicago  chicago  il  usa, northwestern univ.  chicago  il  usa',
#        'sch. of software  tsinghua univ.  beijing  china, sch. of software  tsinghua univ.  beijing  china, sch. of software  tsinghua univ.  beijing  china, sch. of software  tsinghua univ.  beijing  china',
#        'nanyang technol. univ.  singapore  singapore, univ. of adelaide  adelaide  sa  australia, univ. of adelaide  adelaide  sa  australia, univ. of adelaide  adelaide  sa  australia',
#        'imperial coll. london  london  uk, imperial coll. london  london  uk',
#        'na, na, na, na, na, na', 'na, na, na', 'na, na, na, na',
#        'na, na, na, na, na, na, na', 'na, na, na, na, na, na, na',
#        'boston coll.  boston  ma  usa, univ. of texas at austin  austin  tx  usa',
#        'na, na, na, na, na',
#        'nat. univ. of singapore  singapore  singapore, inst. for infocomm res.  astar  singapore  singapore, inst. for infocomm res.  astar  singapore  singapore, univ. of minnesota  minneapolis  mn  usa, nat. univ. of singapore  singapore  singapore',
#        'nielsen  madrid  spain, uber technol.  san francisco  ca  usa, york univ.  toronto  on  canada, york univ.  toronto  on  canada',
#        'univ. of michigan  ann arbor  mi  usa, univ. of michigan  ann arbor  mi  usa, univ. of michigan  ann arbor  mi  usa, univ. of michigan  ann arbor  mi  usa, univ. of michigan  ann arbor  mi  usa, univ. of michigan  ann arbor  mi  usa',
#        'dept. of autom.  tsinghua univ.  beijing  china, dept. of autom.  tsinghua univ.  beijing  china, dept. of autom.  tsinghua univ.  beijing  china, dept. of autom.  tsinghua univ.  beijing  china, dept. of autom.  tsinghua univ.  beijing  china',
#        'eth zυrich  zürich  swaziland, eth zυrich  zürich  swaziland, eth zυrich  zürich  swaziland, vizrt india private ltd.  new delhi  india, eth zυrich  zürich  swaziland',
#        'dept. of comput. sci.  wayne state univ.  detroit  mi  usa, dept. of math.  wayne state univ.  detroit  mi  usa, dept. of comput. sci.  wayne state univ.  detroit  mi  usa, res. & innovation center  ford motor co.  dearborn  mi  usa, res. & innovation center  ford motor co.  dearborn  mi  usa',
#        'na, na, na', 'na, na, na',
#        'southwest jiaotong univ.  jiaotong  china, southwest jiaotong univ.  jiaotong  china, alibaba group  hangzhou  china, alibaba group  hangzhou  china',
#        'na, na, na, na, na',
#        'the university of adelaide, the university of adelaide, the university of adelaide',
#        'na, na, na',
#        'massachusetts inst. of technol.  cambridge  md  usa, univ. of massachusetts  amherst  ma  usa, massachusetts inst. of technol.  cambridge  md  usa, deepmind  google  london  uk, massachusetts inst. of technol.  cambridge  md  usa',
#        'dept. of eng. sci.  univ. of oxford  oxford  uk, dept. of eng. sci.  univ. of oxford  oxford  uk, dept. of eng. sci.  univ. of oxford  oxford  uk, dept. of eng. sci.  univ. of oxford  oxford  uk',
#        'google brain  google  london  uk, google res. new york  new york  ny  usa, google brain mountain view  mountain view  ca  usa, google brain mountain view  mountain view  ca  usa, google res. new york  new york  ny  usa',
#        'sch. of electr. eng.  ulsan nat. inst. of sci. & technol.  ulsan  south korea, sch. of electr. eng.  ulsan nat. inst. of sci. & technol.  ulsan  south korea',
#        'fac. of electr. eng.  czech tech. univ. in prague  prague  czech republic, fac. of electr. eng.  czech tech. univ. in prague  prague  czech republic',
#        'max planck inst. for intell. syst.  tϋbingen  germany, max planck inst. for intell. syst.  tϋbingen  germany, max planck inst. for intell. syst.  tϋbingen  germany',
#        'sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore, sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore, sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore',
#        'na, na, na, na, na',
#        'interdiscipl. grad. sch.  nanyang technol. univ.  singapore  singapore, interdiscipl. grad. sch.  nanyang technol. univ.  singapore  singapore, interdiscipl. grad. sch.  nanyang technol. univ.  singapore  singapore',
#        'twitter  san francisco  ca  usa, twitter  san francisco  ca  usa, twitter  san francisco  ca  usa, twitter  san francisco  ca  usa, twitter  san francisco  ca  usa, twitter  san francisco  ca  usa, twitter  san francisco  ca  usa',
#        'dept. of comput. sci. & eng.  univ. of bologna  bologna  italy, dept. of comput. sci. & eng.  univ. of bologna  bologna  italy',
#        'na, na, na, na',
#        'inst. of comput. sci. & technol.  peking univ.  beijing  china, inst. of comput. sci. & technol.  peking univ.  beijing  china, inst. of comput. sci. & technol.  peking univ.  beijing  china, inst. of comput. sci. & technol.  peking univ.  beijing  china',
#        'ens cachan  univ. paris-saclay  cachan  france, na, na',
#        'chinese univ. of hong kong  hong kong  china, chinese univ. of hong kong  hong kong  china, chinese univ. of hong kong  hong kong  china, massachuate inst. of technol.  cambridge  ma  usa, sensetime group ltd.  china, chinese univ. of hong kong  hong kong  china',
#        'beijing key lab. of iot inf. security  beijing  china, state key lab. of virtual reality technol. & syst.  beihang univ.  beijing  china, beijing key lab. of iot inf. security  beijing  china, beijing key lab. of iot inf. security  beijing  china',
#        'blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel, blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel',
#        'na, na, na', 'na, na, na, na',
#        'univ. of cambridge  cambridge  uk, univ. of cambridge  cambridge  uk',
#        'stanford univ.  stanford  ca  usa, stanford univ.  stanford  ca  usa, stanford univ.  stanford  ca  usa, stanford univ.  stanford  ca  usa, hkust  hong kong  china, univ. of california  berkeley  berkeley  ca  usa, stanford univ.  stanford  ca  usa',
#        'dept. of comput. sci.  univ. of north carolina at chapel hill  chapel hill  nc  usa, dept. of comput. sci.  univ. of north carolina at chapel hill  chapel hill  nc  usa, dept. of comput. sci.  univ. of north carolina at chapel hill  chapel hill  nc  usa, dept. of comput. sci.  univ. of north carolina at chapel hill  chapel hill  nc  usa',
#        'dept. of cognitive sci.  xiamen univ.  xiamen  china, miovision technol. inc.  canada, miovision technol. inc.  canada, miovision technol. inc.  canada, dept. of cognitive sci.  xiamen univ.  xiamen  china, dept. of comput. sci.  univ. of sherbrooke  sherbrooke  qc  canada',
#        'na, na',
#        'ljk  univ. grenoble alpes  grenoble  france, ljk  univ. grenoble alpes  grenoble  france, ljk  univ. grenoble alpes  grenoble  france',
#        'na, na, na, na, na',
#        'dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china, dept. of inf. eng.  chinese univ. of hong kong  hong kong  china',
#        'na, na, na, na, na',
#        'imati  milan  italy, univ. of maryland  college park  md  usa, univ. of maryland  college park  md  usa, max planck inst. for intell. syst.  tubingen  germany',
#        'dept. of comput. sci.  univ. of maryland  college park  md  usa, inst. de telecomun.  univ. de lisboa  lisbon  portugal, dept. of math.  hong kong baptist univ.  kowloon  china, sch. of electr. & comput. eng.  cornell univ.  ithaca  ny  usa, dept. of comput. sci.  univ. of maryland  college park  md  usa',
#        'microsoft res.  univ. of sci. & technol. of china  beijing  china, microsoft res.  univ. of sci. & technol. of china  beijing  china, microsoft res.  univ. of sci. & technol. of china  beijing  china, microsoft res.  univ. of sci. & technol. of china  beijing  china',
#        'ait lab  eth zurich, computer vision lab  eth zurich, computer vision lab  eth zurich, ait lab  eth zurich',
#        'dept. of cise  univ. of florida  gainesville  fl  usa, richard petersens plads  tech. univ. of denmark  lyngby  denmark, dept. of cise  univ. of florida  gainesville  fl  usa',
#        'uc berkeley  berkeley  ca  usa, google  usa, uc berkeley  berkeley  ca  usa, google  usa, uc berkeley  berkeley  ca  usa',
#        'univ. of konstanz  konstanz  germany, univ. of konstanz  konstanz  germany, univ. of konstanz  konstanz  germany',
#        'center for res. in comput. vision  univ. of central florida  orlando  fl  usa, center for res. in comput. vision  univ. of central florida  orlando  fl  usa, center for res. in comput. vision  univ. of central florida  orlando  fl  usa',
#        'dept. of comput. sci.  univ. of manitoba winnipeg  winnipeg  mb  canada, dept. of comput. sci.  univ. of manitoba winnipeg  winnipeg  mb  canada, dept. of comput. sci.  univ. of manitoba winnipeg  winnipeg  mb  canada, dept. of comput. sci.  univ. of manitoba winnipeg  winnipeg  mb  canada',
#        'tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany',
#        'univ. of california  los angeles  los angeles  ca  usa, univ. of california  los angeles  los angeles  ca  usa, univ. of california  los angeles  los angeles  ca  usa, univ. of california  los angeles  los angeles  ca  usa',
#        'shandong univ.  jinan  china, univ. of western ontario  london  on  canada, key lab. of intell. comput. & inf. security  univ. of shandong  jinan  china, shandong univ.  jinan  china, shandong univ.  jinan  china, univ. of western ontario  london  on  canada',
#        'inst. for robot. & intell. syst.  usc  playa vista  ca  usa, inf. sci. inst.  usc  playa vista  ca  usa, inst. for robot. & intell. syst.  usc  playa vista  ca  usa, inst. for robot. & intell. syst.  usc  playa vista  ca  usa',
#        'state key lab. for novel software technol.  nanjing univ.  nanjing  china, univ. of michigan  ann arbor  mi  usa, state key lab. for novel software technol.  nanjing univ.  nanjing  china, univ. of michigan  ann arbor  mi  usa',
#        'nvidia, nvidia, nvidia, nvidia', 'na, na, na',
#        'sri int.  princeton  nj  usa, state univ. of rio de janeiro  rio de janeiro  brazil, brown univ.  providence  ri  usa',
#        'sci. & technol. on integrated inf. syst. lab.  inst. of software  beijing  china, sci. & technol. on integrated inf. syst. lab.  inst. of software  beijing  china',
#        'na, na, na, na, na',
#        'inst. of artificial intell.  zhejiang univ.  hangzhou  china, inst. of artificial intell.  zhejiang univ.  hangzhou  china, inst. of artificial intell.  zhejiang univ.  hangzhou  china, inst. of artificial intell.  zhejiang univ.  hangzhou  china, inst. of artificial intell.  zhejiang univ.  hangzhou  china',
#        'sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore, sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore, sch. of electr. & electron. eng.  nanyang technol. univ.  singapore  singapore',
#        'blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel, blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel, blavatnik sch. of comput. sci.  tel aviv univ.  tel-aviv  israel',
#        'na, na, na, na, na, na',
#        'dept. of comput. sci. & technol.  tsinghua univ.  beijing  china, dept. of comput. sci. & technol.  tsinghua univ.  beijing  china, intel labs. china  beijing  china, dept. of comput. sci. & technol.  tsinghua univ.  beijing  china, dept. of electron. eng.  tsinghua univ.  beijing  china, intel labs. china  beijing  china',
#        'na, na, na, na, na',
#        'visual comput. inst.  rwth aachen univ.  aachen  germany, visual comput. inst.  rwth aachen univ.  aachen  germany, visual comput. inst.  rwth aachen univ.  aachen  germany',
#        'australian nat. univ.  canberra  act  australia, univ. of western australia  perth  wa  australia, australian nat. univ.  canberra  act  australia',
#        'dept. of comput. sci.  cornell univ.  ithaca  ny  usa, na, na, na, na, dept. of comput. sci.  cornell univ.  ithaca  ny  usa',
#        'na, na, na, na',
#        'dept. of comput. sci.  cornell univ.  ithaca  ny  usa, dept. of comput. sci.  cornell univ.  ithaca  ny  usa, sch. of electr. & comput. eng.  cornell univ.  ithaca  ny  usa, dept. of comput. sci.  cornell univ.  ithaca  ny  usa, dept. of comput. sci.  cornell univ.  ithaca  ny  usa',
#        'mimesis group  inria  strasbourg  france, mimesis group  inria  strasbourg  france',
#        'univ. of california  merced  merced  ca  usa, univ. of california  merced  merced  ca  usa, na, univ. of california  merced  merced  ca  usa',
#        'na, na, na, na, na, na',
#        'heidelberg collaboratory for image process.  heidelberg univ.  heidelberg  germany, heidelberg collaboratory for image process.  heidelberg univ.  heidelberg  germany',
#        'na, na, na, na, na, na',
#        'cvssp  univ. of surrey  guildford  uk, cvssp  univ. of surrey  guildford  uk',
#        'pattern recognition lab.  delft univ. of technol.  delft  netherlands, language technol. inst.  carnegie mellon univ.  pittsburgh  pa  usa, pattern recognition lab.  delft univ. of technol.  delft  netherlands, language technol. inst.  carnegie mellon univ.  pittsburgh  pa  usa',
#        'california inst. of technol.  pasadena  ca  usa, california inst. of technol.  pasadena  ca  usa',
#        'nikon corp.  sagamihara  japan, nikon corp.  sagamihara  japan',
#        'nat. lab. of pattern recognition  univ. of chinese acad. of sci.  beijing  china, nat. lab. of pattern recognition  univ. of chinese acad. of sci.  beijing  china, nat. lab. of pattern recognition  univ. of chinese acad. of sci.  beijing  china, nat. lab. of pattern recognition  univ. of chinese acad. of sci.  beijing  china, birkbeck  univ. of london  london  uk',
#        'na, na, na',
#        'beijing univ. of posts & telecommun.  beijing  china, beijing univ. of posts & telecommun.  beijing  china, beijing univ. of posts & telecommun.  beijing  china',
#        'sch. of comput. & commun. sci.  ecole polytech. fed. de lausanne  lausanne  switzerland, sch. of comput. & commun. sci.  ecole polytech. fed. de lausanne  lausanne  switzerland',
#        'univ. of delaware  newark  de  usa, univ. of delaware  newark  de  usa, univ. of delaware  newark  de  usa, univ. of delaware  newark  de  usa, univ. of delaware  newark  de  usa, u.s. army res. lab.  adelphi  md  usa, u.s. army res. lab.  adelphi  md  usa, univ. of delaware  newark  de  usa',
#        'northwestern polytech. univ.  xian  china, australian centre for robotic vision  brisbane  qld  australia, univ. of adelaide  adelaide  sa  australia, the university of adelaide  australia',
#        'key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china, key lab. of intell. inf. process.  inst. of comput. technol.  beijing  china',
#        'inst. de rob`otica i inform`atica ind.  barcelona  spain, inst. de rob`otica i inform`atica ind.  barcelona  spain',
#        'australian centre for visual technol.  univ. of adelaide  adelaide  sa  australia, australian centre for visual technol.  univ. of adelaide  adelaide  sa  australia, australian centre for visual technol.  univ. of adelaide  adelaide  sa  australia',
#        'zhejiang univ.  hangzhou  china, columbia univ.  new york  ny  usa, zhejiang univ.  hangzhou  china, shandong univ.  jinan  china, zhejiang univ.  hangzhou  china, tencent ai lab.  shenzhen  china, nat. univ. of singapore  singapore  singapore',
#        'univ. of canberra  canberra  act  australia, univ. of canberra  canberra  act  australia, khalifa univ.  abu dhabi  united arab emirates, univ. of canberra  canberra  act  australia',
#        'dept. of comput. sci. & technol.  nanjing univ.  nanjing  china, dept. of comput. sci. & technol.  nanjing univ.  nanjing  china',
#        'center for autom. res.  univ. of maryland  college park  md  usa, dept. of electr. & comput. eng.  rutgers univ.  piscataway  nj  usa, center for autom. res.  univ. of maryland  college park  md  usa',
#        'dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa',
#        'dept. of electr. & comput. eng.  rutgers univ.  piscataway  nj  usa, dept. of electr. & comput. eng.  rutgers univ.  piscataway  nj  usa, dept. of electr. & comput. eng.  rutgers univ.  piscataway  nj  usa, dept. of comput. sci.  drexel univ.  philadelphia  pa  usa',
#        'na, na, na, na',
#        'microsoft res.  beijing  china, microsoft res.  beijing  china, microsoft res.  beijing  china, microsoft res.  beijing  china',
#        'vision lab.  delft univ. of technol.  delft  netherlands, vision lab.  delft univ. of technol.  delft  netherlands, vision lab  delft university of technology  delft  netherlands',
#        'state key lab. of inf. security  iie  china, state key lab. of inf. security  iie  china, state key lab. of inf. security  iie  china, state key lab. of inf. security  iie  china, state key lab. of inf. security  iie  china',
#        'na, na, na, na, na',
#        'nat. univ. of singapore  singapore  singapore, nat. univ. of singapore  singapore  singapore',
#        'univ. of massachusetts amherst  amherst  ma  usa, univ. of cyprus  nicosia  cyprus, univ. of massachusetts amherst  amherst  ma  usa, iit bombay  mumbai  india',
#        'dept. inf.  ecole normale super.  paris  france',
#        'na, na, na, na',
#        'res. lab.  u.s. army  usa, res. lab.  u.s. army  usa',
#        'iwr  heidelberg univ.  heidelberg  germany, iwr  heidelberg univ.  heidelberg  germany, iwr  heidelberg univ.  heidelberg  germany',
#        'center for res. on intell. perception & comput.  nat. lab. of pattern recognition  china, center for res. on intell. perception & comput.  nat. lab. of pattern recognition  china',
#        'na, na, na, na, na',
#        'eth zurich, eth zurich, ku leuven, university of bonn',
#        'carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa',
#        'na, na, na', 'na, na, na, na',
#        'tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany, na, tech. univ. dresden  dresden  germany, na, tech. univ. dresden  dresden  germany',
#        'carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, isr - ist  univ. de lisboa  lisbon  portugal, isr - ist  univ. de lisboa  lisbon  portugal',
#        'na, na, na, na',
#        'univ. of oxford  oxford  uk, univ. of oxford  oxford  uk',
#        'quva lab.  univ. of amsterdam  amsterdam  netherlands, quva lab.  univ. of amsterdam  amsterdam  netherlands, quva lab.  univ. of amsterdam  amsterdam  netherlands, quva lab.  univ. of amsterdam  amsterdam  netherlands, quva lab.  univ. of amsterdam  amsterdam  netherlands',
#        'imperial coll. london  london  uk, imperial coll. london  london  uk, na, iit jodhpur  jodhpur  india, imperial coll. london  london  uk',
#        'cvlab  epfl  lausanne  switzerland, cvlab  epfl  lausanne  switzerland, cvlab  epfl  lausanne  switzerland',
#        'centrale supelec  univ. paris-saclay  paris  france, centrale supelec  univ. paris-saclay  paris  france',
#        'sch. of comput.  wuhan univ.  wuhan  china, sch. of comput.  wuhan univ.  wuhan  china, sch. of comput.  wuhan univ.  wuhan  china, state key lab. of software eng.  wuhan univ.  wuhan  china',
#        'na, na, na, na, na, na',
#        'sch. of eee  nanyang technol. univ.  singapore  singapore, sch. of eee  nanyang technol. univ.  singapore  singapore, adv. digital sci. center  univ. of illinois at urbana-champaign  singapore  singapore, alibaba group  beijing  china',
#        'unc chapel hill  chapel hill  nc  usa, stevens inst. of technol.  hoboken  nj  usa, unc chapel hill  chapel hill  nc  usa',
#        'na, skolkovo inst. of sci. & technol.  moscow  russia',
#        'disney res.  pittsburgh  pa  usa, disney res.  pittsburgh  pa  usa',
#        'dept. of comput. sci. & eng.  shanghai jiao tong univ.  shanghai  china, dept. of comput. sci. & eng.  shanghai jiao tong univ.  shanghai  china, dept. of comput. sci. & eng.  shanghai jiao tong univ.  shanghai  china, dept. of comput. sci. & eng.  shanghai jiao tong univ.  shanghai  china',
#        'grad. sch. of convergence sci. & technol.  seoul nat. univ.  seoul  south korea, dept. of electr. & comput. eng.  seoul nat. univ.  seoul  south korea, dept. of electr. & electron. eng.  imperial coll. london  london  uk, dept. of electr. & electron. eng.  imperial coll. london  london  uk, dept. of electr. & comput. eng.  seoul nat. univ.  seoul  south korea',
#        'na, na, na, na', 'na, na, na, na',
#        'univ. of british columbia  vancouver  bc  canada, mpi for intell. syst.  tubingen  germany, body labs. inc.  new york  ny  usa',
#        'list  cea  gif-sur-yvette  france, list  cea  gif-sur-yvette  france, mics  univ. of paris-saclay  châtenay-malabry  france',
#        'postech  pohang  south korea, na, na',
#        'cornell univ.  ithaca  ny  usa, adobe  san jose  ca  usa, adobe  san jose  ca  usa, cornell univ.  ithaca  ny  usa',
#        'robot. inst.  carnegie mellon univ.  carnegie  ny  usa, robot. inst.  carnegie mellon univ.  carnegie  ny  usa',
#        'australian nat. univ.  canberra  act  australia, australian nat. univ.  canberra  act  australia, australian nat. univ.  canberra  act  australia',
#        'na, na',
#        'univ. of alberta  edmonton  ab  canada, memorial univ. of newfoundland  st. johns  nl  canada, univ. of alberta  edmonton  ab  canada',
#        'max planck inst. for inf.  saarbrucken  germany, daimler ag r&d  sindelfingen  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany, comput. vision lab.  tech. univ. dresden  dresden  germany, comput. vision lab.  tech. univ. dresden  dresden  germany, comput. vision lab.  univ. of freiburg  freiburg  germany, max planck inst. for inf.  saarbrucken  germany, max planck inst. for inf.  saarbrucken  germany',
#        'na, na, na, na',
# ...
#        'na, na',
#        'virginia tech  blacksburg  va  usa, salesforce res.  usa, georgia inst. of technol.  atlanta  ga  usa, salesforce res.  usa',
#        'ee  kaist  daejeon  south korea, ee  kaist  daejeon  south korea, ee  kaist  daejeon  south korea',
#        'inst. de rob`otica i inform`atica ind.  barcelona  spain',
#        'city coll.  city univ. of new york  new york  ny  usa, here north america llc  usa, city coll.  city univ. of new york  new york  ny  usa',
#        'data61  australian nat. univ.  canberra  act  australia, dept. of eng. sci.  univ. of oxford  oxford  uk, dept. of eng. sci.  univ. of oxford  oxford  uk, comput. vision lab.  epfl  lausanne  switzerland, dept. of eng. sci.  univ. of oxford  oxford  uk, dept. of eng. sci.  univ. of oxford  oxford  uk',
#        'inria  sophia-antipolis  france, body labs. inc.  new york  ny  usa, inria  sophia-antipolis  france, max planck inst. for intell. syst.  tubingen  germany, max planck inst. for intell. syst.  tubingen  germany, inria  sophia-antipolis  france, inria  sophia-antipolis  france',
#        'sun yat-sen univ.  guangzhou  china, chinese univ. of hong kong  hong kong  china, sun yat-sen univ.  guangzhou  china, chinese univ. of hong kong  hong kong  china',
#        'na, na', 'na, na',
#        'dept. of comput. sci. & eng  postech  pohang  south korea, dept. of comput. sci. & eng  postech  pohang  south korea, dept. of comput. sci. & eng  postech  pohang  south korea, dept. of comput. sci. & eng  postech  pohang  south korea',
#        'sch. of autom.  northwestern polytech. univ.  xian  china, res. sch. of eng.  australian nat. univ.  canberra  act  australia, data61  csiro  canberra  act  australia, res. sch. of eng.  australian nat. univ.  canberra  act  australia',
#        'na, na, na, na, na, na',
#        'state key lab. of inf. security  inst. of inf. eng.  beijing  china, state key lab. of inf. security  inst. of inf. eng.  beijing  china, nat. lab. of pattern recognition  inst. of autom.  beijing  china, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, state key lab. of inf. security  inst. of inf. eng.  beijing  china',
#        'na, na',
#        'cai  univ. of technol. sydney  sydney  nsw  australia, na, cai  univ. of technol. sydney  sydney  nsw  australia, na',
#        'fac. of electr. eng.  czech tech. univ. in prague  prague  czech republic, univ. of california  berkeley  berkeley  ca  usa, univ. of california  berkeley  berkeley  ca  usa, fac. of electr. eng.  czech tech. univ. in prague  prague  czech republic',
#        'tech. univ. munich  munich  germany, tel-aviv univ.  tel aviv  israel, usi lugano  lugano  swaziland, intel perceptual comput. group  technion - israel inst. of technol.  haifa  israel, tech. univ. munich  munich  germany',
#        'univ. of california  los angeles  los angeles  ca  usa, shanghai jiao tong univ.  shanghai  china, univ. of california  los angeles  los angeles  ca  usa, univ. of california  los angeles  los angeles  ca  usa, univ. of california  los angeles  los angeles  ca  usa',
#        'univ. of michigan  ann arbor  mi  usa, adobe res.  san jose  ca  usa, adobe res.  san jose  ca  usa, adobe res.  san jose  ca  usa, univ. of michigan  ann arbor  mi  usa',
#        'lip6  upmc univ. paris 06  paris  france, lip6  upmc univ. paris 06  paris  france, conservatoire nat. des arts et metiers  paris  france, lip6  upmc univ. paris 06  paris  france',
#        'na, na, na, na',
#        'comput. vision lab.  eth zurich  zurich  switzerland, comput. vision lab.  eth zurich  zurich  switzerland, comput. vision lab.  eth zurich  zurich  switzerland, comput. vision lab.  eth zurich  zurich  switzerland',
#        'mapir-uma group  univ. of malaga  malaga  spain, mapir-uma group  univ. of malaga  malaga  spain',
#        'tech. univ. dresden  dresden  germany, mpi for inf.  saarbrucken  germany, mpi for inf.  saarbrucken  germany, tech. univ. dresden  dresden  germany, tech. univ. dresden  dresden  germany',
#        'na, na, na, na, na', 'na, na',
#        'carnegie mellon univ.  pittsburgh  pa  usa, univ. of washington  seattle  wa  usa, univ. of washington  seattle  wa  usa, carnegie mellon univ.  pittsburgh  pa  usa',
#        'shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china, shenzhen key lab. of comp. vis. & pat. rec.  shenzhen inst. of adv. technol.  shenzhen  china',
#        'na, na, na, na, na',
#        'centrale supelec  inria  gif-sur-yvette  france, imperial coll. london  london  uk, amazon  berlin  germany, imperial coll. london  london  uk, imperial coll. london  london  uk, univ. coll. london  london  uk',
#        'dept. of comput. sci.  rutgers univ.  piscataway  nj  usa, dept. of comput. sci.  rutgers univ.  piscataway  nj  usa',
#        'na, na, na, na',
#        'univ. of trento  trento  italy, na, chinese univ. of hong kong  hong kong  china, chinese univ. of hong kong  hong kong  china, univ. of trento  trento  italy',
#        'univ. of chinese acad. of sci.  beijing  china, univ. of chinese acad. of sci.  beijing  china, duke univ.  durham  nh  usa, univ. of chinese acad. of sci.  beijing  china',
#        'princeton university, na, stanford university, na, na, na',
#        'na, na, na, na', 'na, na, na, na, na',
#        'australian centre for robotic vision  brisbane  qld  australia, australian centre for robotic vision  brisbane  qld  australia, data61  csiro  sydney  nsw  australia, australian centre for robotic vision  brisbane  qld  australia',
#        'na, na, na, na, na, na, na, na, na, na, na',
#        'media analytics dept.  nec labs. america  cupertino  ca  usa, media analytics dept.  nec labs. america  cupertino  ca  usa',
#        'carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa, carnegie mellon univ.  pittsburgh  pa  usa',
#        'dept. of electr. & electron. eng.  imperial coll. london  london  uk, dept. of electr. & electron. eng.  imperial coll. london  london  uk',
#        'ucla vision lab.  univ. of california  los angeles  los angeles  ca  usa, hrl labs.  llc  malibu  ca  usa, hrl labs.  llc  malibu  ca  usa, hrl labs.  llc  malibu  ca  usa, ucla vision lab.  univ. of california  los angeles  los angeles  ca  usa',
#        'lab. jean kuntzmann  inria  grenoble  france, lab. jean kuntzmann  inria  grenoble  france, lab. jean kuntzmann  inria  grenoble  france',
#        'na, na, na',
#        'cornell university, tsinghua university, facebook ai research, cornell university',
#        'inst. of autom.  beijing  china, inst. of autom.  beijing  china',
#        'na, na, na, na, na, na',
#        'sch. of comput. sci.  univ. of east anglia  norwich  uk, center for future media  univ. of electron. sci. & technol. of china  chengdu  china, sch. of comput. sci.  univ. of east anglia  norwich  uk, sch. of comput. sci. & eng.  beihang univ.  beijing  china, sch. of comput. sci.  univ. of east anglia  norwich  uk',
#        'princeton univ.  princeton  nj  usa, princeton univ.  princeton  nj  usa',
#        'technion - israel inst. of technol.  haifa  israel, technion - israel inst. of technol.  haifa  israel',
#        'dept. of comput. sci.  eth zurich  zurich  switzerland, dept. of comput. sci.  eth zurich  zurich  switzerland, dept. of comput. sci.  eth zurich  zurich  switzerland, dept. of comput. sci.  eth zurich  zurich  switzerland, dept. of comput. sci.  eth zurich  zurich  switzerland',
#        'beijing inst. of technol.  beijing  china, na, nat. univ. of singapore  singapore  singapore, beijing inst. of technol.  beijing  china, nat. univ. of singapore  singapore  singapore, nat. univ. of singapore  singapore  singapore',
#        'dept. of electr. & comput. eng.  northeastern univ.  boston  ma  usa, dept. of electr. & comput. eng.  northeastern univ.  boston  ma  usa, dept. of electr. & comput. eng.  northeastern univ.  boston  ma  usa',
#        'univ. of cambridge  cambridge  ma  usa, na, univ. of cambridge  cambridge  ma  usa, na',
#        'fujitsu r&d center  beijing  china, fujitsu r&d center  beijing  china',
#        'na, na, na, na, na, na, na', 'na, na, na, na',
#        'oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa, oregon state univ.  corvallis  or  usa',
#        'na, na, na',
#        'chinese univ. of hong kong  hong kong  china, chinese univ. of hong kong  hong kong  china, chinese univ. of hong kong  hong kong  china, tsinghua univ.  beijing  china, johns hopkins univ.  baltimore  md  usa, chinese univ. of hong kong  hong kong  china',
#        'na, na, na, na, na, na, na, na',
#        'univ. of california  san diego  la jolla  ca  usa, na, na, na, univ. of california  san diego  la jolla  ca  usa',
#        'indian inst. of sci.  bangalore  india, indian inst. of sci.  bangalore  india, indian inst. of sci.  bangalore  india',
#        'sch. of comput. sci. & technol.  tianjin univ.  tianjin  china, sch. of comput. sci. & technol.  tianjin univ.  tianjin  china, inst. for infocomm res.  agency for sci.  technol. & res.  singapore  singapore, sch. of comput. sci. & technol.  tianjin univ.  tianjin  china, state key lab. of inf. security  iie  china',
#        'video analytics lab.  indian inst. of sci.  bangalore  india, video analytics lab.  indian inst. of sci.  bangalore  india, video analytics lab.  indian inst. of sci.  bangalore  india',
#        'sch. of comput. sci. & technol.  harbin inst. of technol.  harbin  china, sch. of comput. sci. & technol.  harbin inst. of technol.  harbin  china, sch. of inf. & commun. eng.  dalian univ. of technol.  dalian  china, sch. of inf. & commun. eng.  dalian univ. of technol.  dalian  china, bio-comput. res. center  harbin inst. of technol.  shenzhen  china, sch. of comput. sci. & technol.  harbin inst. of technol.  harbin  china',
#        'univ. of western ontario  london  on  canada, univ. of western ontario  london  on  canada, univ. of pennsylvania  philadelphia  pa  usa, univ. of iowa  iowa city  ia  usa, univ. of western ontario  london  on  canada',
#        'na, na, na, na, na, na', 'na, na, na, na, na',
#        'univ. of california  davis  davis  ca  usa, zhejiang univ.  hangzhou  china, univ. of california  davis  davis  ca  usa',
#        'visual comput. inst.  rwth aachen univ.  aachen  germany, visual comput. inst.  rwth aachen univ.  aachen  germany, visual comput. inst.  rwth aachen univ.  aachen  germany, visual comput. inst.  rwth aachen univ.  aachen  germany',
#        'state key lab. of synthetical autom. for process ind.  northeastern univ.  shenyang  china, dept. of autom.  tsinghua univ.  beijing  china, state key lab. of synthetical autom. for process ind.  northeastern univ.  shenyang  china, dept. of autom.  tsinghua univ.  beijing  china, state key lab. of synthetical autom. for process ind.  northeastern univ.  shenyang  china, dept. of autom.  tsinghua univ.  beijing  china',
#        'univ. of technol. sydney  sydney  nsw  australia, utsa  san antonio  tx  usa, ustc  hefei  china, ucsd  la jolla  ca  usa, univ. of technol. sydney  sydney  nsw  australia, utsa  san antonio  tx  usa',
#        'tsinghua univ.  beijing  china, carnegie mellon univ.  pittsburgh  pa  usa',
#        'bernstein center for comput. neurosci.  tubingen  germany, body labs. inc.  new york  ny  usa, mpi for intell. syst.  tubingen  germany, microsoft  cambridge  uk, mpi for intell. syst.  tubingen  germany, univ. of wurzburg  wurzburg  germany',
#        'king abdullah univ. of sci. & technol.  thuwal  saudi arabia, sch. of data & comput. sci.  sun yat-sen univ.  guangzhou  china, king abdullah univ. of sci. & technol.  thuwal  saudi arabia',
#        'sch. of comput. sci. & technol.  anhui univ.  hefei  china, sch. of comput. sci. & technol.  anhui univ.  hefei  china, cse dept.  univ. of texas at arlington  arlington  tx  usa, sch. of comput. sci. & technol.  anhui univ.  hefei  china',
#        'dept. of comput. sci.  univ. of california  irvine  irvine  ca  usa, dept. of comput. sci.  univ. of california  irvine  irvine  ca  usa',
#        'na, na, na, na, na',
#        'key lab. of intell. inf. process.  inst. of comput. tech  china, key lab. of intell. inf. process.  inst. of comput. tech  china, key lab. of intell. inf. process.  inst. of comput. tech  china',
#        'sch. of comput. sci. & eng.  hebrew univ. of jerusalem  jerusalem  israel, sch. of comput. sci. & eng.  hebrew univ. of jerusalem  jerusalem  israel',
#        'na, na, cvlab  epfl  lausanne  switzerland',
#        'ist austria  klosterneuburg  austria, na, na, na, na',
#        'nat. inst. of adv. ind. sci. & technol.  tsukuba  japan, nat. inst. of adv. ind. sci. & technol.  tsukuba  japan',
#        'sch. of inf. & commun. eng.  beijing univ. of posts & telecommun.  beijing  china, sch. of inf. & commun. eng.  beijing univ. of posts & telecommun.  beijing  china, sch. of comput. sci.  beijing univ. of posts & telecommun.  beijing  china',
#        'tencent ai lab.  shenzhen  china, johns hopkins univ.  baltimore  md  usa',
#        'dept. of electr. & electron. eng.  yonsei univ.  seoul  south korea, dept. of electr. & electron. eng.  yonsei univ.  seoul  south korea',
#        'centre for vision  speech & signal process.  univ. of surrey  guildford  uk, centre for vision  speech & signal process.  univ. of surrey  guildford  uk, centre for vision  speech & signal process.  univ. of surrey  guildford  uk, centre for vision  speech & signal process.  univ. of surrey  guildford  uk, sch. of iot eng.  jiangnan univ.  wuxi  china',
#        'sch. of comput. sci. & eng.  ntu  singapore  singapore, ihpc  a*star  singapore  singapore, sch. of comput. sci. & eng.  ntu  singapore  singapore, sch. of comput. sci. & eng.  ntu  singapore  singapore',
#        'inst. for theor. comput. sci.  tsinghua univ.  beijing  china, sch. of electron. eng. & comput. sci.  peking univ.  beijing  china, megvii inc.  beijing  china, megvii inc.  beijing  china',
#        'dept. of comput. sci. & eng.  michigan state univ.  east lansing  mi  usa, dept. of comput. sci. & eng.  michigan state univ.  east lansing  mi  usa, dept. of comput. sci. & eng.  michigan state univ.  east lansing  mi  usa',
#        'facebook ai res.  usa, facebook ai res.  usa, dept. of comput. sci.  rutgers univ.  new brunswick  nj  usa, facebook ai res.  usa',
#        'univ. coll. london  london  uk, turing inst.  univ. of edinburgh  edinburgh  uk, univ. coll. london  london  uk',
#        'na, na, na, na, na', 'na, na, na, na',
#        'univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of warwick  coventry  uk',
#        'univ. of tennessee  knoxville  tn  usa, univ. of tennessee  knoxville  tn  usa, univ. of tennessee  knoxville  tn  usa',
#        'na, na, na, na', 'na, na, na, na', 'na, na, na',
#        'center for imaging sci.  johns hopkins univ.  baltimore  md  usa, center for imaging sci.  johns hopkins univ.  baltimore  md  usa',
#        'univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk, univ. of oxford  oxford  uk',
#        'na, na, na, na, na, na',
#        'singapore univ. of technol. & design  singapore  singapore, artificial intell. res. center  nat. inst. of aist  tsukuba  japan, singapore univ. of technol. & design  singapore  singapore, artificial intell. res. center  nat. inst. of aist  tsukuba  japan'],
#       dtype=object)

# %%
nips_collab = {2017:0, 2018:0,2019:0,2020:0,2021:0}
years = list(nips_collab.keys())
names = [affil_nips_2017,affil_nips_2018,affil_nips_2019,affil_nips_2020,affil_nips_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords) and any(key in temp[j] for key in industry_kewords): 
            nips_collab[year]+=1

# %%
icml_collab = {2017:0, 2018:0,2019:0,2020:0, 2021:0}
years = list(icml_collab.keys())
names = [affil_icml_2017,affil_icml_2018,affil_icml_2019,affil_icml_2020,affil_icml_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords) and any(key in temp[j] for key in industry_kewords): 
            icml_collab[year]+=1

# %%
cvpr_collab = {2017:0, 2018:0,2019:0,2020:0,2021:0}
years = list(cvpr_collab.keys())
names = [affil_cvpr_2017,affil_cvpr_2018,affil_cvpr_2019,affil_cvpr_2020,affil_cvpr_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in uni_keywords) and any(key in temp[j] for key in industry_kewords): 
            cvpr_collab[year]+=1

# %%
nips_collab
# Out:
# {2017: 215, 2018: 294, 2019: 449, 2020: 613, 2021: 764}

# %%
icml_collab
# Out:
# {2017: 104, 2018: 162, 2019: 238, 2020: 313, 2021: 363}

# %%
iclr_collab
# Out:
# {2017: 50, 2018: 144, 2019: 198, 2020: 44, 2021: 172}

# %%
cvpr_collab
# Out:
# {2017: 89, 2018: 153, 2019: 378, 2020: 596, 2021: 607}

# %%
total_collab = dict()
for key in list(nips_collab.keys()):
    total_collab[key] = nips_collab[key] + icml_collab[key] + iclr_collab[key] + cvpr_collab[key]

fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(total_collab.keys()))
bar_width = 0.2
axs.bar(years, total_collab.values(), width=bar_width, label = 'Collaboration')
axs.set_xticks(years)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Collaborations between university and industry in each year', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Collaborations between university and industry in each year')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(nips_collab.keys()))
bar_width = 0.2
axs.bar(years, nips_collab.values(), width=bar_width, label = 'Collaboration')
axs.set_xticks(years)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Collaborations between university and industry in NeurIPS', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Collaborations between university and industry in NeurIPS')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(icml_collab.keys()))
bar_width = 0.2
axs.bar(years, icml_collab.values(), width=bar_width, label = 'Collaboration')
axs.set_xticks(years)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Collaborations between university and industry in ICML', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Collaborations between university and industry in ICML')

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(iclr_collab.keys()))
bar_width = 0.2
axs.bar(years, iclr_collab.values(), width=bar_width, label = 'Collaboration')
axs.set_xticks(years)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Collaborations between university and industry in ICLR', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Collaborations between university and industry in ICLR')

# %%
ucsd_nips_collab = {2017:0, 2018:0,2019:0,2020:0}
ucsd_key = ['ucsd', 'uc san diego', 'university of california san diego',\
            'university of california at san diego','university of california, san diego','university of california']
years = list(ucsd_nips_collab.keys())
names = [affil_nips_2017,affil_nips_2018,affil_nips_2019,affil_nips_2020]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in ucsd_key) and any(key in temp[j] for key in industry_kewords): 
            ucsd_nips_collab[year]+=1

# %%
ucsd_nips_collab
# Out:
# {2017: 8, 2018: 6, 2019: 20, 2020: 23}

# %%
ucsd_key = ['ucsd', 'uc san diego', 'univerisity of california san diego',\
            'univerisity of california, san diego','univerisity of california']

# %%
ucsd_nips = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(ucsd_nips.keys())
names = [affil_nips_2017,affil_nips_2018,affil_nips_2019,affil_nips_2020,affil_nips_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in ucsd_key) and any(key in temp[j] for key in industry_kewords) : 
            ucsd_nips[year]+=1

ucsd_icml = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(ucsd_icml.keys())
names = [affil_icml_2017,affil_icml_2018,affil_icml_2019,affil_icml_2020,affil_icml_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in ucsd_key) and any(key in temp[j] for key in industry_kewords) : 
            ucsd_icml[year]+=1
            
ucsd_iclr = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(ucsd_iclr.keys())
names = [affil_iclr_2017,affil_iclr_2018,affil_iclr_2019,affil_iclr_2020,affil_iclr_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in ucsd_key) and any(key in temp[j] for key in industry_kewords) : 
            ucsd_iclr[year]+=1

ucsd_cvpr = {2017:0, 2018:0,2019:0,2020:0,2021:0}

years = list(ucsd_cvpr.keys())
names = [affil_cvpr_2017,affil_cvpr_2018,affil_cvpr_2019,affil_cvpr_2020,affil_cvpr_2021]
for i in range(len(names)):
    year = years[i]
    temp = names[i]
    for j in range(len(temp)):
        if any(key in temp[j] for key in ucsd_key) and any(key in temp[j] for key in industry_kewords) : 
            ucsd_cvpr[year]+=1

# %%
ucsd_iclr
# Out:
# {2017: 0, 2018: 0, 2019: 1, 2020: 1, 2021: 2}

# %%
ucsd_icml
# Out:
# {2017: 3, 2018: 0, 2019: 2, 2020: 2, 2021: 2}

# %%
ucsd_nips
# Out:
# {2017: 1, 2018: 1, 2019: 6, 2020: 7, 2021: 5}

# %%
ucsd_collab = {2017:0, 2018:0,2019:0,2020:0,2021:0}
years = list(ucsd_collab.keys())
for year in (years): 
    ucsd_collab[year] = ucsd_nips[year] + ucsd_icml[year] + ucsd_iclr[year] + ucsd_cvpr[year]

# %%
ucsd_collab
# Out:
# {2017: 6, 2018: 2, 2019: 13, 2020: 15, 2021: 19}

# %%
fig,axs = subplots(figsize = (10,8))
years = np.asarray(list(ucsd_collab.keys()))
bar_width = 0.2
axs.bar(years, ucsd_collab.values(), width=bar_width, label = 'Collaboration')
axs.set_xticks(years)
axs.set_xticklabels(years)
axs.legend(fontsize = 10)
axs.set_title('Collaborations between UCSD and Industries', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Collaborations between UCSD and Industries')
